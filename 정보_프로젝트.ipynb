# %% [markdown]
# <a href="https://colab.research.google.com/github/Seungwon0127/CS-project/blob/main/%EC%A0%95%EB%B3%B4_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# gemini
# 1. 모든 동물의 최상위 공통 부모 클래스
class Animal:
    def __init__(self, name, location, speed, vision_range):
        # 계획서에 명시된 공통 속성 초기화
        self.name = name
        self.health = 100
        self.hunger = 0
        self.location = location
        self.speed = speed
        self.age = 0
        self.vision_range = vision_range
        self.alive = True

    # 계획서에 명시된 공통 메서드 (틀만 잡아둠)
    def move(self):
        pass

    def rest(self):
        pass

    def lose_energy(self):
        pass

    def die(self):
        self.alive = False

    def eat(self):
        pass

    def reproduce(self):
        pass

    def update(self):
        pass


# 2. 피식자들을 위한 하위 소비자 클래스 (Animal 상속)
class PrimaryConsumer(Animal):
    def __init__(self, name, location, speed, vision_range, growth_rate):
        # 부모(Animal)의 속성을 그대로 가져와서 씀
        super().__init__(name, location, speed, vision_range)
        # 하위 소비자만의 고유 속성 추가
        self.growth_rate = growth_rate

    # 하위 소비자만의 고유 메서드
    def be_eaten(self):
        self.die()
        print(f"[{self.name}]이(가) 포식자에게 먹혔습니다.")


# 3. 실제 동물 객체: 크릴새우 (PrimaryConsumer 상속)
class Krill(PrimaryConsumer):
    def __init__(self, location):
        # 크릴새우에 맞는 기본 스탯을 넣어 부모 클래스 호출
        super().__init__(name="크릴새우", location=location, speed=2, vision_range=5, growth_rate=1.5)

    # 크릴새우는 별도의 고유 속성/메서드 없이 부모의 것을 그대로 사용


# 4. 실제 동물 객체: 조개 (PrimaryConsumer 상속)
class Clam(PrimaryConsumer):
    def __init__(self, location, burrow_depth):
        # 조개에 맞는 기본 스탯 (이동 속도 0 등) 설정
        super().__init__(name="조개", location=location, speed=0, vision_range=1, growth_rate=1.1)
        # 조개만의 고유 속성 추가
        self.burrow_depth = burrow_depth

    # 조개만의 고유 메서드
    def stay_on_seafloor(self):
        print(f"[{self.name}]이(가) 해저 깊이 {self.burrow_depth}에 머뭅니다.")
